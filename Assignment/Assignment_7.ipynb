# %% [markdown]
# <a href="https://colab.research.google.com/github/GayathriGalli/umbc_data690_fall2024/blob/main/Assignment/Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10/16/2024

# %%
import pandas as pd
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

print(df.shape)
df.sample(3)
# Out:
# (4123, 9)
#      Year        Country  GDP per capita (current US$)  \
# 35   2020        Albania                   5343.037704
# 43   2009        Algeria                   3898.478788
# 910  2021  Cote d'Ivoire                   2613.378893
#
#      Life expectancy at birth, total (years)  Population, total Country Code  \
# 35                                    76.989          2837849.0          ALB
# 43                                    73.620         35196037.0          DZA
# 910                                   58.598         27478249.0          CIV
#
#                          Region         Income Group Lending Type
# 35        Europe & Central Asia  Upper middle income         IBRD
# 43   Middle East & North Africa  Lower middle income         IBRD
# 910         Sub-Saharan Africa   Lower middle income          IDA

# %%
column_names_dict = {
    "GDP per capita (current US$)" : "GDP per Capita",
    "Life expectancy at birth, total (years)" : "Life Expectancy",
    "Population, total" : "Population"
}

df = df.rename(columns=column_names_dict)
df.sample(3)
# Out:
#       Year          Country  GDP per Capita  Life Expectancy  Population  \
# 3521  2010            Sudan     1706.414917           63.016  33739933.0
# 3329  2008  Solomon Islands     1504.527495           68.404    516001.0
# 1137  2020      El Salvador     3961.726633           71.061   6292731.0
#
#      Country Code                      Region         Income Group  \
# 3521          SDN         Sub-Saharan Africa            Low income
# 3329          SLB         East Asia & Pacific  Lower middle income
# 1137          SLV  Latin America & Caribbean   Upper middle income
#
#      Lending Type
# 3521          IDA
# 3329          IDA
# 1137         IBRD

# %%
df.sample(3).T
# Out:
#                                 2846                   3574  \
# Year                            2019                   2006
# Country                     Pakistan            Switzerland
# GDP per Capita           1437.165833           59011.032459
# Life Expectancy               66.756              81.490244
# Population               223293280.0              7483934.0
# Country Code                     PAK                    CHE
# Region                    South Asia  Europe & Central Asia
# Income Group     Lower middle income            High income
# Lending Type                   Blend         Not classified
#
#                                 2310
# Year                            2015
# Country                     Maldives
# GDP per Capita           9480.431514
# Life Expectancy               79.695
# Population                  435582.0
# Country Code                     MDV
# Region                    South Asia
# Income Group     Upper middle income
# Lending Type                     IDA

# %% [markdown]
# ## Section One
#
# Summary Statistics with describe() function

# %%
df[["Population","Life Expectancy"]].describe()
# Out:
#          Population  Life Expectancy
# count  4.123000e+03      3777.000000
# mean   3.319575e+07        71.060853
# std    1.316430e+08         8.499806
# min    9.791000e+03        42.125000
# 25%    7.436200e+05        65.351000
# 50%    5.872624e+06        72.765000
# 75%    2.148494e+07        77.529000
# max    1.417173e+09        85.497561

# %%
df.describe()
# Out:
#              Year  GDP per Capita  Life Expectancy    Population
# count  4123.00000     3962.000000      3777.000000  4.123000e+03
# mean   2013.00000    17007.692848        71.060853  3.319575e+07
# std       5.47789    25733.109164         8.499806  1.316430e+08
# min    2004.00000      128.538423        42.125000  9.791000e+03
# 25%    2008.00000     1862.892400        65.351000  7.436200e+05
# 50%    2013.00000     6048.304202        72.765000  5.872624e+06
# 75%    2018.00000    22137.309568        77.529000  2.148494e+07
# max    2022.00000   240862.182448        85.497561  1.417173e+09

# %%
df.describe(include="object")
# Out:
#             Country Country Code                 Region Income Group  \
# count          4123         4123                   4123         4123
# unique          217          217                      7            5
# top     Afghanistan          AFG  Europe & Central Asia  High income
# freq             19           19                   1102         1558
#
#           Lending Type
# count             4123
# unique               4
# top     Not classified
# freq              1387

# %%
df.describe(include="object").T
# Out:
#              count unique                    top  freq
# Country       4123    217            Afghanistan    19
# Country Code  4123    217                    AFG    19
# Region        4123      7  Europe & Central Asia  1102
# Income Group  4123      5            High income  1558
# Lending Type  4123      4         Not classified  1387

# %% [markdown]
# ## Section Two
#
# Compute quartiles and transform a numerical column into a categorical column based on the quartiles.

# %%
def assign_quartile(gdp):
    if gdp <= 1862.89:
        quartile = "1st Quartile (<=25%)"
    elif gdp > 1862.89 and gdp <= 6048.30:
        quartile = "2nd Quartile (25-50%)"
    elif gdp > 6048.30 and gdp <= 22137.31:
        quartile = "3rd Quartile (50-75%)"
    else:
        quartile = "4th Quartile (>75%)"
    return quartile


hungary = assign_quartile(14294.25)
hungary
# Out:
# '3rd Quartile (50-75%)'

# %%
df_usa = df[df["Country Code"] == "USA"]
df_usa
# Out:
#       Year        Country  GDP per Capita  Life Expectancy   Population  \
# 3914  2004  United States    41724.631629        77.487805  292805298.0
# 3915  2005  United States    44123.407068        77.487805  295516599.0
# 3916  2006  United States    46302.000880        77.687805  298379912.0
# 3917  2007  United States    48050.223777        77.987805  301231207.0
# 3918  2008  United States    48570.045980        78.039024  304093966.0
# 3919  2009  United States    47194.943355        78.390244  306771529.0
# 3920  2010  United States    48650.643128        78.541463  309327143.0
# 3921  2011  United States    50065.966504        78.641463  311583481.0
# 3922  2012  United States    51784.418574        78.741463  313877662.0
# 3923  2013  United States    53291.127689        78.741463  316059947.0
# 3924  2014  United States    55123.849787        78.841463  318386329.0
# 3925  2015  United States    56762.729452        78.690244  320738994.0
# 3926  2016  United States    57866.744934        78.539024  323071755.0
# 3927  2017  United States    59907.754261        78.539024  325122128.0
# 3928  2018  United States    62823.309438        78.639024  326838199.0
# 3929  2019  United States    65120.394663        78.787805  328329953.0
# 3930  2020  United States    63528.634303        76.980488  331511512.0
# 3931  2021  United States    70219.472454        76.329268  332031554.0
# 3932  2022  United States    76329.582265              NaN  333287557.0
#
#      Country Code         Region Income Group    Lending Type
# 3914          USA  North America  High income  Not classified
# 3915          USA  North America  High income  Not classified
# 3916          USA  North America  High income  Not classified
# 3917          USA  North America  High income  Not classified
# 3918          USA  North America  High income  Not classified
# 3919          USA  North America  High income  Not classified
# 3920          USA  North America  High income  Not classified
# 3921          USA  North America  High income  Not classified
# 3922          USA  North America  High income  Not classified
# 3923          USA  North America  High income  Not classified
# 3924          USA  North America  High income  Not classified
# 3925          USA  North America  High income  Not classified
# 3926          USA  North America  High income  Not classified
# 3927          USA  North America  High income  Not classified
# 3928          USA  North America  High income  Not classified
# 3929          USA  North America  High income  Not classified
# 3930          USA  North America  High income  Not classified
# 3931          USA  North America  High income  Not classified
# 3932          USA  North America  High income  Not classified

# %%
assign_quartile(76329.58)
# Out:
# '4th Quartile (>75%)'

# %%
df_2020 = df[df["Year"] == 2020]
print(df_2020.shape[0])
print(f"There are {df_2020.shape[0]} countries in the 2020 dataset")
df_2020.sample(3)
# Out:
# 217
# There are 217 countries in the 2020 dataset
#       Year      Country  GDP per Capita  Life Expectancy  Population  \
# 491   2020     Botswana     5875.070606           65.647   2546402.0
# 3398  2020  South Sudan             NaN           55.480  10606227.0
# 1498  2020      Grenada     8437.536782           74.924    123663.0
#
#      Country Code                      Region         Income Group  \
# 491           BWA         Sub-Saharan Africa   Upper middle income
# 3398          SSD         Sub-Saharan Africa            Low income
# 1498          GRD  Latin America & Caribbean   Upper middle income
#
#      Lending Type
# 491          IBRD
# 3398          IDA
# 1498        Blend

# %%
# Tuple
df_2020.shape
# Out:
# (217, 9)

# %% [markdown]
# ## In-class Exercise
#
# Create a new column call "GDP Quartile" in the df_2020 dataframe and assign each country the quartile it belongs to by applying the assign_quartile() function.

# %%
df_2020["GDP Quartile"] = df_2020["GDP per Capita"].apply(assign_quartile)

print(df_2020.shape[0])
print(df_2020["GDP Quartile"].value_counts())
# Out:
# 217
# GDP Quartile
# 4th Quartile (>75%)      61
# 2nd Quartile (25-50%)    58
# 3rd Quartile (50-75%)    54
# 1st Quartile (<=25%)     44
# Name: count, dtype: int64

# %%
df_2020.sample(10)
# Out:
#       Year                Country  GDP per Capita  Life Expectancy  \
# 3588  2020            Switzerland    85897.784334        83.000000
# 3759  2020                Tunisia     3497.719027        75.292000
# 2125  2020                Lesotho      917.356381        54.693000
# 4044  2020  Virgin Islands (U.S.)    39411.045254        79.819512
# 871   2020            Congo, Rep.     2011.269479        63.785000
# 1878  2020                  Japan    39986.928629        84.560000
# 396   2020                  Benin     1240.733155        60.088000
# 1232  2020               Ethiopia      918.652594        65.371000
# 434   2020                 Bhutan     3181.339747        71.609000
# 985   2020                 Cyprus    28281.425781        81.391000
#
#        Population Country Code                      Region  \
# 3588    8638167.0          CHE       Europe & Central Asia
# 3759   12161723.0          TUN  Middle East & North Africa
# 2125    2254100.0          LSO         Sub-Saharan Africa
# 4044     106290.0          VIR  Latin America & Caribbean
# 871     5702174.0          COG         Sub-Saharan Africa
# 1878  126261000.0          JPN         East Asia & Pacific
# 396    12643123.0          BEN         Sub-Saharan Africa
# 1232  117190911.0          ETH         Sub-Saharan Africa
# 434      772506.0          BTN                  South Asia
# 985     1237537.0          CYP       Europe & Central Asia
#
#              Income Group    Lending Type           GDP Quartile
# 3588          High income  Not classified    4th Quartile (>75%)
# 3759  Lower middle income            IBRD  2nd Quartile (25-50%)
# 2125  Lower middle income             IDA   1st Quartile (<=25%)
# 4044          High income  Not classified    4th Quartile (>75%)
# 871   Lower middle income           Blend  2nd Quartile (25-50%)
# 1878          High income  Not classified    4th Quartile (>75%)
# 396   Lower middle income             IDA   1st Quartile (<=25%)
# 1232           Low income             IDA   1st Quartile (<=25%)
# 434   Lower middle income             IDA  2nd Quartile (25-50%)
# 985           High income  Not classified    4th Quartile (>75%)

# %%
df_4th = df_2020[df_2020["GDP Quartile"] == "4th Quartile (>75%)"]
df_4th.shape
# Out:
# (61, 10)

# %%
", ".join(list(df_4th["Country"]))
# Out:
# "Andorra, Aruba, Australia, Austria, Bahamas, The, Bahrain, Belgium, Bermuda, British Virgin Islands, Brunei Darussalam, Canada, Cayman Islands, Channel Islands, Cyprus, Czechia, Denmark, Eritrea, Estonia, Faroe Islands, Finland, France, Germany, Gibraltar, Greenland, Guam, Hong Kong SAR, China, Iceland, Ireland, Isle of Man, Israel, Italy, Japan, Korea, Dem. People's Rep., Korea, Rep., Kuwait, Liechtenstein, Luxembourg, Macao SAR, China, Malta, Monaco, Netherlands, New Caledonia, New Zealand, Norway, Portugal, Puerto Rico, Qatar, San Marino, Singapore, Sint Maarten (Dutch part), Slovenia, South Sudan, Spain, St. Martin (French part), Sweden, Switzerland, United Arab Emirates, United Kingdom, United States, Venezuela, RB, Virgin Islands (U.S.)"

# %%
quartile_groups = df_2020.groupby("GDP Quartile")["Country"].apply(list)


for quartile, countries in quartile_groups.items():
  print(f"{quartile}:")
  for country in countries:
      print(f"  - {country}")
  print("\n")
# Out:
# 1st Quartile (<=25%):
#   - Afghanistan
#   - Angola
#   - Benin
#   - Burkina Faso
#   - Burundi
#   - Cambodia
#   - Cameroon
#   - Central African Republic
#   - Chad
#   - Comoros
#   - Congo, Dem. Rep.
#   - Ethiopia
#   - Gambia, The
#   - Guinea
#   - Guinea-Bissau
#   - Haiti
#   - Kiribati
#   - Kyrgyz Republic
#   - Lesotho
#   - Liberia
#   - Madagascar
#   - Malawi
#   - Mali
#   - Mauritania
#   - Mozambique
#   - Myanmar
#   - Nepal
#   - Niger
#   - Pakistan
#   - Rwanda
#   - Senegal
#   - Sierra Leone
#   - Somalia
#   - Sudan
#   - Syrian Arab Republic
#   - Tajikistan
#   - Tanzania
#   - Timor-Leste
#   - Togo
#   - Uganda
#   - Uzbekistan
#   - Yemen, Rep.
#   - Zambia
#   - Zimbabwe
#
#
# 2nd Quartile (25-50%):
#   - Albania
#   - Algeria
#   - Armenia
#   - Azerbaijan
#   - Bangladesh
#   - Belize
#   - Bhutan
#   - Bolivia
#   - Botswana
#   - Cabo Verde
#   - Colombia
#   - Congo, Rep.
#   - Cote d'Ivoire
#   - Djibouti
#   - Ecuador
#   - Egypt, Arab Rep.
#   - El Salvador
#   - Eswatini
#   - Fiji
#   - Georgia
#   - Ghana
#   - Guatemala
#   - Honduras
#   - India
#   - Indonesia
#   - Iran, Islamic Rep.
#   - Iraq
#   - Jamaica
#   - Jordan
#   - Kenya
#   - Kosovo
#   - Lao PDR
#   - Lebanon
#   - Marshall Islands
#   - Micronesia, Fed. Sts.
#   - Moldova
#   - Mongolia
#   - Morocco
#   - Namibia
#   - Nicaragua
#   - Nigeria
#   - North Macedonia
#   - Papua New Guinea
#   - Paraguay
#   - Philippines
#   - Samoa
#   - Sao Tome and Principe
#   - Solomon Islands
#   - South Africa
#   - Sri Lanka
#   - Suriname
#   - Tonga
#   - Tunisia
#   - Tuvalu
#   - Ukraine
#   - Vanuatu
#   - Viet Nam
#   - West Bank and Gaza
#
#
# 3rd Quartile (50-75%):
#   - American Samoa
#   - Antigua and Barbuda
#   - Argentina
#   - Barbados
#   - Belarus
#   - Bosnia and Herzegovina
#   - Brazil
#   - Bulgaria
#   - Chile
#   - China
#   - Costa Rica
#   - Croatia
#   - Cuba
#   - Curacao
#   - Dominica
#   - Dominican Republic
#   - Equatorial Guinea
#   - French Polynesia
#   - Gabon
#   - Greece
#   - Grenada
#   - Guyana
#   - Hungary
#   - Kazakhstan
#   - Latvia
#   - Libya
#   - Lithuania
#   - Malaysia
#   - Maldives
#   - Mauritius
#   - Mexico
#   - Montenegro
#   - Nauru
#   - Northern Mariana Islands
#   - Oman
#   - Palau
#   - Panama
#   - Peru
#   - Poland
#   - Romania
#   - Russian Federation
#   - Saudi Arabia
#   - Serbia
#   - Seychelles
#   - Slovak Republic
#   - St. Kitts and Nevis
#   - St. Lucia
#   - St. Vincent and the Grenadines
#   - Thailand
#   - Trinidad and Tobago
#   - Turkiye
#   - Turkmenistan
#   - Turks and Caicos Islands
#   - Uruguay
#
#
# 4th Quartile (>75%):
#   - Andorra
#   - Aruba
#   - Australia
#   - Austria
#   - Bahamas, The
#   - Bahrain
#   - Belgium
#   - Bermuda
#   - British Virgin Islands
#   - Brunei Darussalam
#   - Canada
#   - Cayman Islands
#   - Channel Islands
#   - Cyprus
#   - Czechia
#   - Denmark
#   - Eritrea
#   - Estonia
#   - Faroe Islands
#   - Finland
#   - France
#   - Germany
#   - Gibraltar
#   - Greenland
#   - Guam
#   - Hong Kong SAR, China
#   - Iceland
#   - Ireland
#   - Isle of Man
#   - Israel
#   - Italy
#   - Japan
#   - Korea, Dem. People's Rep.
#   - Korea, Rep.
#   - Kuwait
#   - Liechtenstein
#   - Luxembourg
#   - Macao SAR, China
#   - Malta
#   - Monaco
#   - Netherlands
#   - New Caledonia
#   - New Zealand
#   - Norway
#   - Portugal
#   - Puerto Rico
#   - Qatar
#   - San Marino
#   - Singapore
#   - Sint Maarten (Dutch part)
#   - Slovenia
#   - South Sudan
#   - Spain
#   - St. Martin (French part)
#   - Sweden
#   - Switzerland
#   - United Arab Emirates
#   - United Kingdom
#   - United States
#   - Venezuela, RB
#   - Virgin Islands (U.S.)

# %%
for quartile, countries in quartile_groups.items():
  print(f"{quartile}:")
  for country in countries:
      print(f"  - {country}")
  print("\n")
# Out:
# 1st Quartile (<=25%):
#   - Afghanistan
#   - Angola
#   - Benin
#   - Burkina Faso
#   - Burundi
#   - Cambodia
#   - Cameroon
#   - Central African Republic
#   - Chad
#   - Comoros
#   - Congo, Dem. Rep.
#   - Ethiopia
#   - Gambia, The
#   - Guinea
#   - Guinea-Bissau
#   - Haiti
#   - Kiribati
#   - Kyrgyz Republic
#   - Lesotho
#   - Liberia
#   - Madagascar
#   - Malawi
#   - Mali
#   - Mauritania
#   - Mozambique
#   - Myanmar
#   - Nepal
#   - Niger
#   - Pakistan
#   - Rwanda
#   - Senegal
#   - Sierra Leone
#   - Somalia
#   - Sudan
#   - Syrian Arab Republic
#   - Tajikistan
#   - Tanzania
#   - Timor-Leste
#   - Togo
#   - Uganda
#   - Uzbekistan
#   - Yemen, Rep.
#   - Zambia
#   - Zimbabwe
#
#
# 2nd Quartile (25-50%):
#   - Albania
#   - Algeria
#   - Armenia
#   - Azerbaijan
#   - Bangladesh
#   - Belize
#   - Bhutan
#   - Bolivia
#   - Botswana
#   - Cabo Verde
#   - Colombia
#   - Congo, Rep.
#   - Cote d'Ivoire
#   - Djibouti
#   - Ecuador
#   - Egypt, Arab Rep.
#   - El Salvador
#   - Eswatini
#   - Fiji
#   - Georgia
#   - Ghana
#   - Guatemala
#   - Honduras
#   - India
#   - Indonesia
#   - Iran, Islamic Rep.
#   - Iraq
#   - Jamaica
#   - Jordan
#   - Kenya
#   - Kosovo
#   - Lao PDR
#   - Lebanon
#   - Marshall Islands
#   - Micronesia, Fed. Sts.
#   - Moldova
#   - Mongolia
#   - Morocco
#   - Namibia
#   - Nicaragua
#   - Nigeria
#   - North Macedonia
#   - Papua New Guinea
#   - Paraguay
#   - Philippines
#   - Samoa
#   - Sao Tome and Principe
#   - Solomon Islands
#   - South Africa
#   - Sri Lanka
#   - Suriname
#   - Tonga
#   - Tunisia
#   - Tuvalu
#   - Ukraine
#   - Vanuatu
#   - Viet Nam
#   - West Bank and Gaza
#
#
# 3rd Quartile (50-75%):
#   - American Samoa
#   - Antigua and Barbuda
#   - Argentina
#   - Barbados
#   - Belarus
#   - Bosnia and Herzegovina
#   - Brazil
#   - Bulgaria
#   - Chile
#   - China
#   - Costa Rica
#   - Croatia
#   - Cuba
#   - Curacao
#   - Dominica
#   - Dominican Republic
#   - Equatorial Guinea
#   - French Polynesia
#   - Gabon
#   - Greece
#   - Grenada
#   - Guyana
#   - Hungary
#   - Kazakhstan
#   - Latvia
#   - Libya
#   - Lithuania
#   - Malaysia
#   - Maldives
#   - Mauritius
#   - Mexico
#   - Montenegro
#   - Nauru
#   - Northern Mariana Islands
#   - Oman
#   - Palau
#   - Panama
#   - Peru
#   - Poland
#   - Romania
#   - Russian Federation
#   - Saudi Arabia
#   - Serbia
#   - Seychelles
#   - Slovak Republic
#   - St. Kitts and Nevis
#   - St. Lucia
#   - St. Vincent and the Grenadines
#   - Thailand
#   - Trinidad and Tobago
#   - Turkiye
#   - Turkmenistan
#   - Turks and Caicos Islands
#   - Uruguay
#
#
# 4th Quartile (>75%):
#   - Andorra
#   - Aruba
#   - Australia
#   - Austria
#   - Bahamas, The
#   - Bahrain
#   - Belgium
#   - Bermuda
#   - British Virgin Islands
#   - Brunei Darussalam
#   - Canada
#   - Cayman Islands
#   - Channel Islands
#   - Cyprus
#   - Czechia
#   - Denmark
#   - Eritrea
#   - Estonia
#   - Faroe Islands
#   - Finland
#   - France
#   - Germany
#   - Gibraltar
#   - Greenland
#   - Guam
#   - Hong Kong SAR, China
#   - Iceland
#   - Ireland
#   - Isle of Man
#   - Israel
#   - Italy
#   - Japan
#   - Korea, Dem. People's Rep.
#   - Korea, Rep.
#   - Kuwait
#   - Liechtenstein
#   - Luxembourg
#   - Macao SAR, China
#   - Malta
#   - Monaco
#   - Netherlands
#   - New Caledonia
#   - New Zealand
#   - Norway
#   - Portugal
#   - Puerto Rico
#   - Qatar
#   - San Marino
#   - Singapore
#   - Sint Maarten (Dutch part)
#   - Slovenia
#   - South Sudan
#   - Spain
#   - St. Martin (French part)
#   - Sweden
#   - Switzerland
#   - United Arab Emirates
#   - United Kingdom
#   - United States
#   - Venezuela, RB
#   - Virgin Islands (U.S.)

# %%
df_2020 = df_2020.dropna()
df_2020["GDP (Rounded)"] = df_2020["GDP per Capita"].apply(round)
df_2020.sample(5)
# Out:
#       Year      Country  GDP per Capita  Life Expectancy    Population  \
# 4120  2020     Zimbabwe     1372.696674         61.12400  1.566967e+07
# 1365  2020  Gambia, The      704.030463         62.61200  2.573995e+06
# 2353  2020        Malta    29597.636163         82.34878  5.153320e+05
# 2543  2020      Morocco     3258.269043         73.92000  3.668877e+07
# 795   2020        China    10408.719554         78.07700  1.411100e+09
#
#      Country Code                      Region         Income Group  \
# 4120          ZWE         Sub-Saharan Africa   Lower middle income
# 1365          GMB         Sub-Saharan Africa            Low income
# 2353          MLT  Middle East & North Africa          High income
# 2543          MAR  Middle East & North Africa  Lower middle income
# 795           CHN         East Asia & Pacific  Upper middle income
#
#         Lending Type           GDP Quartile  GDP (Rounded)
# 4120           Blend   1st Quartile (<=25%)           1373
# 1365             IDA   1st Quartile (<=25%)            704
# 2353  Not classified    4th Quartile (>75%)          29598
# 2543            IBRD  2nd Quartile (25-50%)           3258
# 795             IBRD  3rd Quartile (50-75%)          10409

# %%
def pop_million(pop):
    return pop / 1000000


df_2020["Population (Million)"] = df_2020["Population"].apply(pop_million)

df_2020.sample(5)
# Out:
#       Year      Country  GDP per Capita  Life Expectancy  Population  \
# 3683  2020  Timor-Leste     1663.559629         68.47500   1299995.0
# 1897  2020       Jordan     3998.673138         75.18400  10928721.0
# 871   2020  Congo, Rep.     2011.269479         63.78500   5702174.0
# 4082  2020  Yemen, Rep.      578.512010         64.65000  32284046.0
# 1821  2020       Israel    44846.791595         82.64878   9215100.0
#
#      Country Code                      Region         Income Group  \
# 3683          TLS         East Asia & Pacific  Lower middle income
# 1897          JOR  Middle East & North Africa  Lower middle income
# 871           COG         Sub-Saharan Africa   Lower middle income
# 4082          YEM  Middle East & North Africa           Low income
# 1821          ISR  Middle East & North Africa          High income
#
#         Lending Type           GDP Quartile  GDP (Rounded)  \
# 3683           Blend   1st Quartile (<=25%)           1664
# 1897            IBRD  2nd Quartile (25-50%)           3999
# 871            Blend  2nd Quartile (25-50%)           2011
# 4082             IDA   1st Quartile (<=25%)            579
# 1821  Not classified    4th Quartile (>75%)          44847
#
#       Population (Million)
# 3683              1.299995
# 1897             10.928721
# 871               5.702174
# 4082             32.284046
# 1821              9.215100

# %%
df_2020["Population2 (Million)"] = df_2020["Population"].apply(lambda pop : pop / 1000000)
df_2020.sample(5)
# Out:
#       Year                Country  GDP per Capita  Life Expectancy  \
# 947   2020                   Cuba     9499.572504        77.567000
# 2448  2020  Micronesia, Fed. Sts.     3639.412699        70.674000
# 396   2020                  Benin     1240.733155        60.088000
# 1669  2020                Hungary    16125.609409        75.568293
# 3778  2020                Turkiye     8638.739133        75.850000
#
#       Population Country Code                      Region  \
# 947   11300698.0          CUB  Latin America & Caribbean
# 2448    112106.0          FSM         East Asia & Pacific
# 396   12643123.0          BEN         Sub-Saharan Africa
# 1669   9750149.0          HUN       Europe & Central Asia
# 3778  83384680.0          TUR       Europe & Central Asia
#
#              Income Group    Lending Type           GDP Quartile  \
# 947   Upper middle income  Not classified  3rd Quartile (50-75%)
# 2448  Lower middle income             IDA  2nd Quartile (25-50%)
# 396   Lower middle income             IDA   1st Quartile (<=25%)
# 1669          High income  Not classified  3rd Quartile (50-75%)
# 3778  Upper middle income            IBRD  3rd Quartile (50-75%)
#
#       GDP (Rounded)  Population (Million)  Population2 (Million)
# 947            9500             11.300698              11.300698
# 2448           3639              0.112106               0.112106
# 396            1241             12.643123              12.643123
# 1669          16126              9.750149               9.750149
# 3778           8639             83.384680              83.384680

# %% [markdown]
# ## Homework Question 1
#
# Save the summary statistics of all numerical columns and all categorical columns to only one Excel spreadsheet file with two worksheets, one for numerical and one for categorical columns.

# %%
# Calculate summary statistics
numerical_summary = df_2020.describe()
categorical_summary = df_2020.describe(include="object").T

# Print the numerical summary
print("Numerical Summary Statistics:")
print(numerical_summary)

# Print the categorical summary
print("\nCategorical Summary Statistics:")
print(categorical_summary)

# Save to Excel
with pd.ExcelWriter("summary_statistics.xlsx") as writer:
    numerical_summary.to_excel(writer, sheet_name="Numerical Summary")
    categorical_summary.to_excel(writer, sheet_name="Categorical Summary")

print("\nSummary statistics saved to summary_statistics.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d723e9a15eef> in <cell line: 2>()
#       1 # Calculate summary statistics
# ----> 2 numerical_summary = df_2020.describe()
#       3 categorical_summary = df_2020.describe(include="object").T
#       4
#       5 # Print the numerical summary
#
# NameError: name 'df_2020' is not defined

# %% [markdown]
# ## Homework Question 2
#
# Create a new column that is the GDP per Capita rounded to 2 decimal points by using the Python's build function "round"
# Hint: apply the round function/method and provide a parameter 2.

# %%
x = 12.23456

y = round(x, 2)
y
# Out:
# 12.23

# %%
df_2020["GDP per Capita (Rounded)"] = df_2020["GDP per Capita"].apply(lambda x: round(x, 2))

df_2020.sample(5)
# Out:
#       Year          Country  GDP per Capita  Life Expectancy  Population  \
# 1099  2020          Ecuador     5645.199290        72.153000  17588595.0
# 2923  2020         Paraguay     5353.348065        73.182000   6618695.0
# 263   2020     Bahamas, The    23998.268019        72.677000    406471.0
# 1593  2020           Guyana     6863.074346        68.486000    797202.0
# 2771  2020  North Macedonia     5965.450232        74.395122   2072531.0
#
#      Country Code                      Region         Income Group  \
# 1099          ECU  Latin America & Caribbean   Upper middle income
# 2923          PRY  Latin America & Caribbean   Upper middle income
# 263           BHS  Latin America & Caribbean           High income
# 1593          GUY  Latin America & Caribbean           High income
# 2771          MKD       Europe & Central Asia  Upper middle income
#
#         Lending Type           GDP Quartile  GDP (Rounded)  \
# 1099            IBRD  2nd Quartile (25-50%)           5645
# 2923            IBRD  2nd Quartile (25-50%)           5353
# 263   Not classified    4th Quartile (>75%)          23998
# 1593             IDA  3rd Quartile (50-75%)           6863
# 2771            IBRD  2nd Quartile (25-50%)           5965
#
#       Population (Million)  Population2 (Million)  GDP per Capita (Rounded)
# 1099             17.588595              17.588595                   5645.20
# 2923              6.618695               6.618695                   5353.35
# 263               0.406471               0.406471                  23998.27
# 1593              0.797202               0.797202                   6863.07
# 2771              2.072531               2.072531                   5965.45

# %% [markdown]
# ## Homework Question 3 (bonus, will cover next week)
#
# step 1 - create a column "Life Expectancy Quartile" similar to the GDP per Capita Quartile above.
# Step 2 - Create a column "health and wealth status" based on the following definition
# - rich and healthy (1st GDP per capita quartile and 1st life expentancy quartile)
# - poor and unhealthy ((4th GDP per capita quartile and 4th life expentancy quartile)
# - rich and unhealthy (1st GDP per capita quartile and 4th life expentancy quartile)
# - poor and healthy ((4th GDP per capita quartile and 1st life expentancy quartile)
# - Other

# %%
# Step 1: Create a Life Expectancy Quartile function
def assign_life_expectancy_quartile(life_expectancy):
    if life_expectancy <= 73:
        quartile = "1st Quartile (<=25%)"
    elif life_expectancy > 73 and life_expectancy <= 80:
        quartile = "2nd Quartile (25-50%)"
    elif life_expectancy > 80 and life_expectancy <= 85:
        quartile = "3rd Quartile (50-75%)"
    else:
        quartile = "4th Quartile (>75%)"
    return quartile

# Apply the function to create the Life Expectancy Quartile column
df_2020["Life Expectancy Quartile"] = df_2020["Life Expectancy"].apply(assign_life_expectancy_quartile)

# Step 2: Create a Health and Wealth Status column
def health_and_wealth_status(row):
    gdp_quartile = row["GDP Quartile"]
    life_expectancy_quartile = row["Life Expectancy Quartile"]

    if gdp_quartile == "1st Quartile (<=25%)" and life_expectancy_quartile == "1st Quartile (<=25%)":
        return "Rich and Healthy"
    elif gdp_quartile == "4th Quartile (>75%)" and life_expectancy_quartile == "4th Quartile (>75%)":
        return "Poor and Unhealthy"
    elif gdp_quartile == "1st Quartile (<=25%)" and life_expectancy_quartile == "4th Quartile (>75%)":
        return "Rich and Unhealthy"
    elif gdp_quartile == "4th Quartile (>75%)" and life_expectancy_quartile == "1st Quartile (<=25%)":
        return "Poor and Healthy"
    else:
        return "Other"

# Apply the function to create the Health and Wealth Status column
df_2020["Health and Wealth Status"] = df_2020.apply(health_and_wealth_status, axis=1)

# Display the updated DataFrame to check the new columns
df_2020.sample(5)
# Out:
#       Year             Country  GDP per Capita  Life Expectancy  Population  \
# 814   2020            Colombia     5304.289129           74.769  50930662.0
# 2505  2020            Mongolia     4041.174146           72.141   3294335.0
# 1745  2020  Iran, Islamic Rep.     2746.419483           74.832  87290193.0
# 1802  2020         Isle of Man    79530.605484           80.588     84046.0
# 2467  2020             Moldova     4376.242493           70.166   2635130.0
#
#      Country Code                      Region         Income Group  \
# 814           COL  Latin America & Caribbean   Upper middle income
# 2505          MNG         East Asia & Pacific  Lower middle income
# 1745          IRN  Middle East & North Africa  Lower middle income
# 1802          IMN       Europe & Central Asia          High income
# 2467          MDA       Europe & Central Asia  Upper middle income
#
#         Lending Type           GDP Quartile  GDP (Rounded)  \
# 814             IBRD  2nd Quartile (25-50%)           5304
# 2505            IBRD  2nd Quartile (25-50%)           4041
# 1745            IBRD  2nd Quartile (25-50%)           2746
# 1802  Not classified    4th Quartile (>75%)          79531
# 2467            IBRD  2nd Quartile (25-50%)           4376
#
#       Population (Million)  Population2 (Million)  GDP per Capita (Rounded)  \
# 814              50.930662              50.930662                   5304.29
# 2505              3.294335               3.294335                   4041.17
# 1745             87.290193              87.290193                   2746.42
# 1802              0.084046               0.084046                  79530.61
# 2467              2.635130               2.635130                   4376.24
#
#      Life Expectancy Quartile Health and Wealth Status
# 814     2nd Quartile (25-50%)                    Other
# 2505     1st Quartile (<=25%)                    Other
# 1745    2nd Quartile (25-50%)                    Other
# 1802    3rd Quartile (50-75%)                    Other
# 2467     1st Quartile (<=25%)                    Other
