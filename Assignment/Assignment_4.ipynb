# %% [markdown]
# <a href="https://colab.research.google.com/github/GayathriGalli/umbc_data690_fall2024/blob/main/Assignment/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 05

# %%
import pandas as pd
import plotly.express as px

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

df.shape
# Out:
# (4123, 9)

# %%
df.sample(5)
# Out:
#       Year          Country  GDP per capita (current US$)  \
# 3201  2013           Serbia                   6755.073675
# 3612  2006       Tajikistan                    401.026829
# 3345  2005          Somalia                           NaN
# 3305  2022  Slovak Republic                  21256.808427
# 1356  2011      Gambia, The                    705.477495
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3201                                75.185366          7164132.0          SRB
# 3612                                67.013000          7057417.0          TJK
# 3345                                50.661000         10467292.0          SOM
# 3305                                      NaN          5431752.0          SVK
# 1356                                61.526000          1998212.0          GMB
#
#                      Region         Income Group    Lending Type
# 3201  Europe & Central Asia  Upper middle income            IBRD
# ...

# %%
df.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               161
# Life expectancy at birth, total (years)    346
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df[["Year", "Country","GDP per capita (current US$)", "Life expectancy at birth, total (years)"]].sample(5)
# Out:
#       Year       Country  GDP per capita (current US$)  \
# 2277  2020        Malawi                    622.184591
# 220   2015       Austria                  44195.817595
# 821   2008       Comoros                   1454.650909
# 806   2012      Colombia                   8096.801510
# 3793  2016  Turkmenistan                   6163.253406
#
#       Life expectancy at birth, total (years)
# 2277                                63.717000
# 220                                 81.190244
# 821                                 60.475000
# 806                                 75.597000
# 3793                                68.777000

# %%
df2 = df[df["Year"] != 2022]
df2.shape
# Out:
# (3906, 9)

# %%
df2.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               140
# Life expectancy at birth, total (years)    129
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df3 = df2.dropna()
df3.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               0
# Life expectancy at birth, total (years)    0
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df3.shape
# Out:
# (3641, 9)

# %% [markdown]
# ## Homework Question 1:
#
# to check if this dataset has duplicate rows. If it has, only keep one from the duplicated rows and drop the rest.

# %%
df_cleaned = df3.drop_duplicates()
print(f"Original shape: {df3.shape}")
print(f"Cleaned shape: {df_cleaned.shape}")
print(df_cleaned.sample(5))
# Out:
# Original shape: (3641, 9)
# Cleaned shape: (3641, 9)
#       Year                         Country  GDP per capita (current US$)  \
# 4074  2012                     Yemen, Rep.                   1349.990610
# 3499  2007  St. Vincent and the Grenadines                   6439.008398
# 558   2011                        Bulgaria                   7857.167070
# 1901  2005                      Kazakhstan                   3771.278957
# 2242  2004                      Madagascar                    277.507827
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 4074                                67.343000         26223391.0          YEM
# 3499                                74.703000           110824.0          VCT
# 558                                 74.163415          7348328.0          BGR
# 1901                                65.860000         15147029.0          KAZ
# 2242                                60.149000         18250774.0          MDG
#
# ...

# %% [markdown]
# ## HW Question 2
#
# Find out if there is a relationship between wealth and health
#
# Pick any year worth of data and use plotly express to generate a scatter plot with GDP as x and life expectancy as y.

# %%
year_of_interest = 2022
df_filtered = df[df["Year"] == year_of_interest]

# Drop rows with NaN values in GDP and Life Expectancy columns
df_filtered = df_filtered.dropna(subset=["GDP per capita (current US$)", "Life expectancy at birth, total (years)"])

# Create a scatter plot
fig = px.scatter(
    df_filtered,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    title=f"Relationship between GDP per Capita and Life Expectancy in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Homework Question 3
#
# Select a year of data. calculate total population of each region and make a pie chart to display the distribution of total population of all regions.

# %%
df_filtered = df_filtered.dropna(subset=["Population, total", "Region"])

population_by_region = df_filtered.groupby("Region")["Population, total"].sum().reset_index()


fig = px.pie(
    population_by_region,
    values='Population, total',
    names='Region',
    title=f"Total Population Distribution by Region in {year_of_interest}",
    labels={'Population, total': 'Total Population'}
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Exercise
#
# Calculate average GDP per capita for  each region and make a bar chart.

# %%
df_cleaned = df.dropna(subset=["GDP per capita (current US$)", "Region"])

average_gdp_by_region = df_cleaned.groupby("Region")["GDP per capita (current US$)"].mean().reset_index()

fig = px.bar(
    average_gdp_by_region,
    x='Region',
    y='GDP per capita (current US$)',
    title='Average GDP per Capita by Region',
    labels={'GDP per capita (current US$)': 'Average GDP per Capita (Current US$)', 'Region': 'Region'},
    text='GDP per capita (current US$)'  # Display values on bars
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_2020 = df3[df3["Year"] == 2020]
df_2020.shape
# Out:
# (202, 9)

# %%
df_2020.sample(5)
# Out:
#       Year                   Country  GDP per capita (current US$)  \
# 3246  2020              Sierra Leone                    493.432241
# 4120  2020                  Zimbabwe                   1372.696674
# 719   2020  Central African Republic                    435.469248
# 187   2020                     Aruba                  24008.127822
# 206   2020                 Australia                  51868.247557
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3246                                   59.763          8233970.0          SLE
# 4120                                   61.124         15669666.0          ZWE
# 719                                    54.604          5343020.0          CAF
# 187                                    75.723           106585.0          ABW
# 206                                    83.200         25649248.0          AUS
#
#                           Region         Income Group    Lending Type
# ...

# %%
df_group = df.groupby("Region")["GDP per capita (current US$)"].mean()
df_group
# Out:
# Region
# East Asia & Pacific           15178.578702
# Europe & Central Asia         32834.037083
# Latin America & Caribbean     13226.709551
# Middle East & North Africa    15653.223444
# North America                 67679.379373
# South Asia                     2357.171555
# Sub-Saharan Africa             2271.143792
# Name: GDP per capita (current US$), dtype: float64

# %%
df_group = df_group.reset_index()
df_group
# Out:
#                        Region  GDP per capita (current US$)
# 0         East Asia & Pacific                  15178.578702
# 1       Europe & Central Asia                  32834.037083
# 2  Latin America & Caribbean                   13226.709551
# 3  Middle East & North Africa                  15653.223444
# 4               North America                  67679.379373
# 5                  South Asia                   2357.171555
# 6         Sub-Saharan Africa                    2271.143792

# %%
fig = px.bar(df_group, x="Region", y="GDP per capita (current US$)", color="Region")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Home work question 4
#
# 1. remove the color legend.
# 2. Order the above bar chart based on the values of the average GDP per capita.

# %%
df_group = df_2020.groupby("Region")["GDP per capita (current US$)"].mean().reset_index()
df_group = df_group.sort_values(by="GDP per capita (current US$)", ascending=False)
fig = px.bar(df_group,
             x="Region",
             y="GDP per capita (current US$)",
             color="Region",
             color_discrete_sequence=px.colors.qualitative.Plotly)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
