# %% [markdown]
# <a href="https://colab.research.google.com/github/GayathriGalli/umbc_data690_fall2024/blob/main/Assignment/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 05

# %%
import pandas as pd
import plotly.express as px

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

df.shape
# Out:
# (4123, 9)

# %%
df.sample(5)
# Out:
#       Year      Country  GDP per capita (current US$)  \
# 2529  2006      Morocco                   2433.212646
# 4027  2022     Viet Nam                   4163.514299
# 3474  2020    St. Lucia                   8951.524766
# 4073  2011  Yemen, Rep.                   1284.617635
# 2590  2010      Namibia                   5445.420063
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 2529                                   69.128         30833022.0          MAR
# 4027                                      NaN         98186856.0          VNM
# 3474                                   73.416           179237.0          LCA
# 4073                                   67.419         25475610.0          YEM
# 2590                                   56.015          2099271.0          NAM
#
#                           Region         Income Group Lending Type
# 2529  Middle East & North Africa  Lower middle income         IBRD
# 4027         East Asia & Pacific  Lower middle income         IBRD
# 3474  Latin America & Caribbean   Upper middle income        Blend
# 4073  Middle East & North Africa           Low income          IDA
# 2590         Sub-Saharan Africa   Upper middle income         IBRD

# %%
df.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               161
# Life expectancy at birth, total (years)    346
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df[["Year", "Country","GDP per capita (current US$)", "Life expectancy at birth, total (years)"]].sample(5)
# Out:
#       Year      Country  GDP per capita (current US$)  \
# 2962  2021  Philippines                   3460.539382
# 2294  2018     Malaysia                  11073.978970
# 1388  2005      Germany                  34520.239649
# 2531  2008      Morocco                   3180.170654
# 2574  2013      Myanmar                   1189.964765
#
#       Life expectancy at birth, total (years)
# 2962                                69.266000
# 2294                                75.644000
# 1388                                78.931707
# 2531                                70.048000
# 2574                                64.815000

# %%
df2 = df[df["Year"] != 2022]
df2.shape
# Out:
# (3906, 9)

# %%
df2.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               140
# Life expectancy at birth, total (years)    129
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df3 = df2.dropna()
df3.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               0
# Life expectancy at birth, total (years)    0
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df3.shape
# Out:
# (3641, 9)

# %% [markdown]
# ## Homework Question 1:
#
# to check if this dataset has duplicate rows. If it has, only keep one from the duplicated rows and drop the rest.

# %%
df_cleaned = df3.drop_duplicates()
print(f"Original shape: {df3.shape}")
print(f"Cleaned shape: {df_cleaned.shape}")
print(df_cleaned.sample(5))
# Out:
# Original shape: (3641, 9)
# Cleaned shape: (3641, 9)
#       Year      Country  GDP per capita (current US$)  \
# 1422  2020        Ghana                   2176.576218
# 219   2014      Austria                  51786.377175
# 1977  2005  Korea, Rep.                  19402.502626
# 999   2015      Czechia                  17829.698322
# 2650  2013  Netherlands                  52198.897561
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 
89065003643,3639.41269869588,4376.24249318339,4041.17414564367,7677.37132106817,3258.26904296875,456.581928995106,1479.61368925363,4252.04172014353,10124.7006220945,1139.18989203941,52162.5701150406,34877.6356349199,41760.5947840005,1876.60737823677,564.841662317524,2074.61374667422,5965.45023195365,68340.0181033702,16707.6230063214,1322.31478539554,13293.3331951688,2446.08468660615,5353.34806456279,6063.62692279047,3224.42281121767,15816.8204021382,22242.406417972,31427.4291136799,52315.6600783117,13047.4566563993,10194.44140625,773.773260850509,4042.72275154324,2155.26586782508,20398.0609870951,1492.47590293523,7733.80346893763,12020.021064317,493.432240551423,61273.9916594455,29223.0696152475,19552.0911095911,25558.4290544506,2222.46211853173,556.578066029269,5753.06649433369,26984.2962770279,3852.38909102194,18553.6571372598,8951.52476578187,8306.36049307201,608.33251953125,4796.53331389928,52837.9039778149,85897.7843338323,537.090234611441,852.330229562269,1104.16442871094,7001.78546023389,1663.5596290755,886.699511508194,4605.97084119137,13705.900228571,3497.71902658991,8638.73913259299,7330.36628793054,20882.2612702141,4674.911402 ...

# %% [markdown]
# ## Homework Question 3
#
# Select a year of data. calculate total population of each region and make a pie chart to display the distribution of total population of all regions.

# %%
df_filtered = df_filtered.dropna(subset=["Population, total", "Region"])

population_by_region = df_filtered.groupby("Region")["Population, total"].sum().reset_index()


fig = px.pie(
    population_by_region,
    values='Population, total',
    names='Region',
    title=f"Total Population Distribution by Region in {year_of_interest}",
    labels={'Population, total': 'Total Population'}
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a893895e-2199-4f54-9861-27159c1911b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a893895e-2199-4f54-9861-27159c1911b6")) {                    Plotly.newPlot(                        "a893895e-2199-4f54-9861-27159c1911b6",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Region=%{label}\u003cbr\u003eTotal Population=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"legendgroup":"","name":"","showlegend":true,"values":[2314369296.0,922172027.0,621758812.0,479966649.0,369582571.0,1882531620.0,1137139986.0],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0 ...

# %% [markdown]
# ## Exercise
#
# Calculate average GDP per capita for  each region and make a bar chart.

# %%
df_cleaned = df.dropna(subset=["GDP per capita (current US$)", "Region"])

average_gdp_by_region = df_cleaned.groupby("Region")["GDP per capita (current US$)"].mean().reset_index()

fig = px.bar(
    average_gdp_by_region,
    x='Region',
    y='GDP per capita (current US$)',
    title='Average GDP per Capita by Region',
    labels={'GDP per capita (current US$)': 'Average GDP per Capita (Current US$)', 'Region': 'Region'},
    text='GDP per capita (current US$)'  # Display values on bars
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3daf30be-0875-4b5b-a1f2-1391779c5032" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3daf30be-0875-4b5b-a1f2-1391779c5032")) {                    Plotly.newPlot(                        "3daf30be-0875-4b5b-a1f2-1391779c5032",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[15178.57870244265,32834.03708256286,13226.709551141275,15653.223443831292,67679.3793732906,2357.1715547168174,2271.14379159153],"textposition":"auto","x":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"xaxis":"x","y":[15178.57870244265,32834.03708256286,13226.709551141275,15653.223443831292,67679.3793732906,2357.1715547168174,2271.14379159153],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{ ...

# %%
df_2020 = df3[df3["Year"] == 2020]
df_2020.shape
# Out:
# (202, 9)

# %%
df_2020.sample(5)
# Out:
#       Year           Country  GDP per capita (current US$)  \
# 3550  2020          Suriname                   4796.533314
# 2201  2020         Lithuania                  20381.855783
# 2600  2020           Namibia                   4252.041720
# 1764  2020              Iraq                   4251.337253
# 2239  2020  Macao SAR, China                  37474.734595
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3550                                72.561000           607065.0          SUR
# 2201                                74.978049          2794885.0          LTU
# 2600                                62.829000          2489098.0          NAM
# 1764                                69.123000         42556984.0          IRQ
# 2239                                85.184000           676283.0          MAC
#
#                           Region         Income Group    Lending Type
# 3550  Latin America & Caribbean   Upper middle income            IBRD
# 2201       Europe & Central Asia          High income  Not classified
# 2600         Sub-Saharan Africa   Upper middle income            IBRD
# 1764  Middle East & North Africa  Upper middle income            IBRD
# 2239         East Asia & Pacific          High income  Not classified

# %%
df_group = df.groupby("Region")["GDP per capita (current US$)"].mean()
df_group
# Out:
# Region
# East Asia & Pacific           15178.578702
# Europe & Central Asia         32834.037083
# Latin America & Caribbean     13226.709551
# Middle East & North Africa    15653.223444
# North America                 67679.379373
# South Asia                     2357.171555
# Sub-Saharan Africa             2271.143792
# Name: GDP per capita (current US$), dtype: float64

# %%
df_group = df_group.reset_index()
df_group
# Out:
#                        Region  GDP per capita (current US$)
# 0         East Asia & Pacific                  15178.578702
# 1       Europe & Central Asia                  32834.037083
# 2  Latin America & Caribbean                   13226.709551
# 3  Middle East & North Africa                  15653.223444
# 4               North America                  67679.379373
# 5                  South Asia                   2357.171555
# 6         Sub-Saharan Africa                    2271.143792

# %%
fig = px.bar(df_group, x="Region", y="GDP per capita (current US$)", color="Region")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8283f543-b6a0-47a1-be4a-379650710d33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8283f543-b6a0-47a1-be4a-379650710d33")) {                    Plotly.newPlot(                        "8283f543-b6a0-47a1-be4a-379650710d33",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[15178.57870244265],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[32834.03708256286],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[13226.709551141275],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[15653.223443831292],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["North America"],"xaxis":"x","y":[67679.3793732906],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[2357.1715547168174],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sub-Saharan Africa ","offsetgroup":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"textposition":"auto","x":["Sub-Saharan Africa "],"xaxis":"x","y":[2271.14379159153],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666 ...

# %% [markdown]
# ## Home work question 4
#
# 1. remove the color legend.
# 2. Order the above bar chart based on the values of the average GDP per capita.

# %%
df_group = df_group.sort_values(by="GDP per capita (current US$)", ascending=False)

fig = px.bar(df_group,
             x="Region",
             y="GDP per capita (current US$)",
             color="Region")

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bcbc4493-b604-48e7-8b13-95f758c47f5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcbc4493-b604-48e7-8b13-95f758c47f5a")) {                    Plotly.newPlot(                        "bcbc4493-b604-48e7-8b13-95f758c47f5a",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["North America"],"xaxis":"x","y":[71556.7328644806],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[31503.269556417392],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[15827.113067012999],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[13990.928453691733],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[11420.61083299391],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[2671.328827387151],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sub-Saharan Africa ","offsetgroup":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"textposition":"auto","x":["Sub-Saharan Africa "],"xaxis":"x","y":[2090.5614138973556],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66 ...
